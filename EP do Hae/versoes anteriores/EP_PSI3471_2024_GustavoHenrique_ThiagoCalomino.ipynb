# %% [markdown]
# # EP - PSI3471 (2024 - $1^o$ semestre)
#
# |Nome do aluno                     |NUSP    |E-mail USP       |
# |----------------------------------|--------|-----------------|
# |Gustavo Henrique da Silva Amaral  |12551686|gustavo.amaral7@usp.br|
# |Thiago da Rocha Calomino Gonçalves|12554647|thcalomino@usp.br|
#
# Prof. Hae Yong Kim
#
# Link: [Enunciado do EP 2024](http://www.lps.usp.br/hae/psi3471/ep1-2024/index.html)

# %% [markdown]
# # Instalação de dependências

# %%
# !pip install opendatasets

import sys
import time
import os
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns

import pandas as pd
import opendatasets as od

import cv2

import tensorflow.keras as keras
from keras.datasets import mnist

from sklearn import tree
from sklearn.metrics import confusion_matrix

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset

from IPython.display import Image
# import requests
# from PIL import Image
# from io import BytesIO

# %% [markdown]
# # Importação dos dados

# %%
kaggletoken = {"username":"thiagocalomino","key":"a04d142f5d19c1c1fbb811d20b50c1f4"}
kaggledataset_pistachio_url = "https://www.kaggle.com/datasets/muratkokludataset/pistachio-image-dataset/data"

# !pip3 install -q kaggle
# !mkdir ~/.kaggle
# !echo '{"username":"thiagocalomino","key":"a04d142f5d19c1c1fbb811d20b50c1f4"}' > ~/.kaggle/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets muratkokludataset/pistachio-image-dataset
# !unzip -u pistachio-image-dataset
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists
# usage: kaggle datasets [-h] {list,files,download,create,version,init,metadata,status} ...
# kaggle datasets: error: argument command: invalid choice: 'muratkokludataset/pistachio-image-dataset' (choose from 'list', 'files', 'download', 'create', 'version', 'init', 'metadata', 'status')
# unzip:  cannot find or open pistachio-image-dataset, pistachio-image-dataset.zip or pistachio-image-dataset.ZIP.

# %%
def findCenterAndOrientation(src):
    M = cv2.moments(src)
    cen_x = 0.0  # Valor padrão para cen_x
    cen_y = 0.0  # Valor padrão para cen_y
    if M["m00"] != 0:
        cen_x = M["m10"] / M["m00"]
        cen_y = M["m01"] / M["m00"]
    theta = 0.5 * math.atan2(2 * M["mu11"], M["mu20"] - M["mu02"])

    return cen_x, cen_y, theta

img = cv2.imread('Jasmine (2).jpg', 0)
Image(filename='Jasmine (2).jpg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-fb4ca1fff8f1> in <cell line: 13>()
#      11
#      12 img = cv2.imread('Jasmine (2).jpg', 0)
# ---> 13 Image(filename='Jasmine (2).jpg')
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# ...

# %%
x, y, theta = findCenterAndOrientation(img)
ponto = (x,y)
